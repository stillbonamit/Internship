# %%
# !pip install selenium

# %%
import selenium 
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By 
import time

# %%
driver = webdriver.Chrome(r"C:\Users\hp\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[] 
job_location=[] 
company_name=[] 
experience_required=[]

# %%
title_tag=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    job_title.append(title)

location_tag=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location=i.text
    job_location.append(location)

comp_tag=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in comp_tag[0:10]:
    company=i.text
    company_name.append(company)

experience_tag=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title,'Location':job_location,'Company Name':company_name,'Experience':experience_required,})
df
# Out:
#                                           Title  \
# 0                     Data Analyst- Yulu Energy
# 1                                  Data Analyst
# 2  Data Analyst - Pharma/hls Domain (4-9 Years)
# 3                                  Data Analyst
# 4                                  Data Analyst
# 5                                  Data Analyst
# 6                                  Data Analyst
# 7                                  Data Analyst
# 8                       Data Analyst Databricks
# 9                                  Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# 2  Bangalore/Bengaluru, Mumbai, Pune, Gurgaon/Gur...
# 3                       Hybrid - Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# ...

# %%
#scrape data for “Data Scientist” Job position in “Bangalore” location
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Scientist")

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title1=[] 
job_location1=[] 
company_name1=[]

# %%
title_tag1=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag1[0:10]:
    title1=i.text
    job_title1.append(title1)

location_tag1=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag1[0:10]:
    location1=i.text
    job_location1.append(location1)

comp_tag1=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in comp_tag1[0:10]:
    company1=i.text
    company_name1.append(company1)

# %%
print(len(job_title1),len(job_location1),len(company_name1))
# Out:
# 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title1,'Location':job_location1,'Company Name':company_name1,})
df
# Out:
#                               Title  \
# 0           Data Science Specialist
# 1  Analystics & Modeling Specialist
# 2                    Data Scientist
# 3              Staff Data Scientist
# 4                Sr. Data scientist
# 5                    Data Scientist
# 6               Lead Data Scientist
# 7             Expert Data Scientist
# 8          Data Scientist Architect
# 9                    Data Scientist
#
#                                             Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 3                        Bangalore/Bengaluru, Mumbai
# 4  Bangalore/Bengaluru, Hyderabad/Secunderabad, M...
# 5  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...
# 6  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 7                        Bangalore/Bengaluru, Mumbai
# 8  Temp. WFH - Bangalore/Bengaluru, Hyderabad/Sec...
# ...

# %%
#scrape data for “Data Scientist” Job position -
#location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

driver = webdriver.Chrome(r"C:\Users\hp\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Scientist")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
driver.execute_script('window.scrollTo(0,500);')

# %%
locdelhi = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]')
locdelhi.click()

# %%
driver.execute_script('window.scrollTo(0,300);')

# %%
Salary = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[1]/div[2]/div[2]')
Salary.click()

# %%
job_title2=[] 
job_location2=[] 
job_salary=[]

# %%
title_tag2=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag2[0:10]:
    title2=i.text
    job_title2.append(title2)

location_tag2=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag2[0:10]:
    location2=i.text
    job_location2.append(location2)

salary_tag=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft "]')
for i in salary_tag[0:10]:
    salary=i.text
    job_salary.append(salary)

# %%
print(len(job_title2),len(job_location2),len(job_salary))
# Out:
# 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title2,'Location - Delhi NCR':job_location2,'Salary 3-6 lakhs':job_salary,})
df
# Out:
#                                  Title  \
# 0          Data Scientist data Analyst
# 1    Data Scientist - Engine Algorithm
# 2                 Analyst-Data Science
# 3                 Analyst-Data Science
# 4   Senior Data Scientist - Statistics
# 5                       Data Scientist
# 6                       Data Scientist
# 7  Associate Data Scientist - ML & NLP
# 8                       Data Scientist
# 9                       Data Scientist
#
#                                 Location - Delhi NCR          Salary 3-6 lakhs
# 0  Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...   1,50,000 - 6,50,000 PA.
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...             Not disclosed
# 2                                   Gurgaon/Gurugram             Not disclosed
# 3                                   Gurgaon/Gurugram             Not disclosed
# 4                                   Gurgaon/Gurugram             Not disclosed
# ...

# %%
#Flipkart sunglasses assignment 

driver = webdriver.Chrome(r"C:\Users\hp\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
popup=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
popup.click()

# %%
product = driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys("sunglasses")

# %%
product_click = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
product_click.click()

# %%
brand_name = []
Product_Description = []
Price = []

# %%
start = 0
end = 1
for page in range(start,end):
    brand = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        brand=i.text
        brand_name.append(i.text)
    
    ProductDes = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in ProductDes:
        ProductDes=i.text
        Product_Description.append(i.text)
    
    Pri = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Pri:
        Pri=i.text
        Price.append(i.text)
    
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand_name),len(Product_Description),len(Price))
# Out:
# 40 40 40

# %%
import pandas as pd
df = pd.DataFrame({'Brand Name':brand_name,'Product Description':Product_Description,'Price1':Price,})
df
# Out:
#         Brand Name                                Product Description  Price1
# 0         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹809
# 1         Fastrack   UV Protection Wrap-around Sunglasses (Free Size)    ₹719
# 2    VINCENT CHASE  Polarized, UV Protection Retro Square Sunglass...    ₹799
# 3        CART2DEAL  Riding Glasses, UV Protection, Mirrored Aviato...  ₹1,274
# 4           PIRASO             UV Protection Wayfarer Sunglasses (32)    ₹214
# 5    VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...    ₹690
# 6         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹632
# 7      Eyewearlabs     Polarized, UV Protection Round Sunglasses (54)  ₹1,424
# 8    VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...    ₹799
# 9           SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...    ₹283
# 10          PIRASO              Polarized Wrap-around Sunglasses (45)    ₹397
# ...

# %%
#Scrape 100 reviews data from flipkart.com for iphone11 phone.

driver = webdriver.Chrome(r"C:\Users\hp\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
RatingPoint=[] 
Reviewsummary=[] 
Fullreview=[]

# %%
start = 0
end = 5
for page in range(start,end):

    rating_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tag:
        rating_tag=i.text
        RatingPoint.append(rating_tag)

    Reviewsummary_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in Reviewsummary_tag:
        Reviewsummary_tag=i.text
        Reviewsummary.append(Reviewsummary_tag)

    Fullreview_tag=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in Fullreview_tag:
        Fullreview_tag=i.text
        Fullreview.append(Fullreview_tag)    
    
    button=driver.find_element(By.XPATH,'//span[contains(text(),"Next")]')
    button.click()
    time.sleep(3)

# %%
len(RatingPoint),len(Reviewsummary),len(Fullreview)
# Out:
# (50, 50, 50)

# %%
import pandas as pd
df = pd.DataFrame({'Rating Point':RatingPoint,'Review Summary':Reviewsummary,'Full Review':Fullreview,})
df
# Out:
#    Rating Point         Review Summary  \
# 0             5         Simply awesome
# 1             5       Perfect product!
# 2             5    Best in the market!
# 3             4        Value-for-money
# 4             5     Highly recommended
# 5             5      Worth every penny
# 6             5       Perfect product!
# 7             5     Highly recommended
# 8             4            Pretty good
# 9             5          Great product
# 10            5              Fabulous!
# 11            5         Classy product
# 12            5      Worth every penny
# 13            5       Perfect product!
# 14            4            Good choice
# 15            4        Value-for-money
# 16            5       Perfect product!
# 17            5     Highly recommended
# 18            5     Highly recommended
# 19            5       Perfect product!
# 20            5     Highly recommended
# 21            5      Worth every penny
# 22            5       Perfect product!
# ...

# %%
#Scrape data for first 100 sneakers you find when you visit flipkart.com

# %%
driver.get("https://www.flipkart.com/")

# %%
product = driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys("sneakers")

# %%
product_click = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
product_click.click()

# %%
Brand1 = []
ProductDes1 = []
PriceTag = []

# %%
start = 0
end = 1
for page in range(start,end):
    sneakersbrand = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in sneakersbrand:
        sneakersbrand=i.text
        Brand1.append(i.text)
    
    ProductDescr = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in ProductDescr:
        ProductDescr=i.text
        ProductDes1.append(i.text)
    
    Pricet = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Pricet:
        Pricet=i.text
        PriceTag.append(i.text)
    
    next_bu=driver.find_element(By.XPATH,'//span[contains(text(),"Next")]')
    next_bu.click()
    time.sleep(3)

# %%
len(Brand1),len(ProductDes1),len(PriceTag)
# Out:
# (40, 40, 40)

# %%
import pandas as pd
df = pd.DataFrame({'Brand':Brand1,'Description':ProductDes1,'Price':PriceTag,})
df
# Out:
#                     Brand                                        Description  \
# 0                  Labbin  Casual Sneakers White Outdoor Shoes For Boys A...
# 1                  Labbin                                   Sneakers For Men
# 2                   BIRDE                                 Sneakers For Women
# 3                     SFR                                   Sneakers For Men
# 4                  BRUTON              Canvas shoes for Men Sneakers For Men
# 5             bacca bucci  BALANCER Men's Fashion Sneakers Lace-Up Traine...
# 6                   BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men
# 7                  Labbin  Casual Sneakers White Shoes For Boys And Men S...
# 8                     SFR                                   Sneakers For Men
# 9                   Sparx                Men White Sneakers Sneakers For Men
# 10                 Shozie  Stylish Sneakers Shoes for Women And Girls Sne...
# ...

# %%
#https://www.amazon.in/ CPU Type filter to “Intel Core i7”

# %%
driver.get("https://www.amazon.in/")

# %%
laptopn = driver.find_element(By.ID,"twotabsearchtextbox")
laptopn.send_keys("laptop")

# %%
laptopsearch = driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')
laptopsearch.click()

# %%
driver.maximize_window()

# %%
driver.execute_script('window.scrollTo(0,1500);')

# %%
CPU = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/li[10]/span/a/div/label/i')
CPU.click()

# %%
laptitle = []
lapratings = []
lapprice = []

# %%
laptoptitle=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in laptoptitle[0:10]:
    title=i.text
    laptitle.append(title)

laptoprating=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in laptoprating[0:10]:
    rating=i.text
    lapratings.append(rating)

laptopprice=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in laptopprice[0:10]:
    price=i.text
    lapprice.append(price)

# %%
len(laptitle), len(lapratings), len(lapprice)
# Out:
# (10, 10, 10)

# %%
import pandas as pd
df = pd.DataFrame({'Title':laptitle,'Ratings':lapratings,'Price':lapprice,})
df
# Out:
#                                                Title Ratings     Price
# 0  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...     4.1    56,990
# 1  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...     4.1    79,990
# 2  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...     4.0    95,990
# 3  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...     4.0    82,990
# 4  MSI GF75 Thin Gaming, Intel Core i7-10750H, 44...     4.4    62,990
# 5  ASUS TUF Gaming F15 (2022), 15.6" (39.62 cms) ...     4.1    94,500
# 6  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...     4.1    65,250
# 7  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...     1.0  1,14,990
# 8  Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdr...     3.8    88,900
# 9  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...     4.3    89,990

# %%
driver.close()

# %%
#Write a python program to scrape data for Top 1000 Quotes of All Time.

# %%
driver = webdriver.Chrome(r"C:\Users\hp\chromedriver.exe")

# %%
driver.get("https://www.azquotes.com/")

# %%
topq = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
topq.click()

# %%
driver.maximize_window()

# %%
Quote = []
Author = []
TypeOfQuotes = []

# %%
start = 0
end = 10
for page in range(start,end):
    topquotes = driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in topquotes:
        topquotes=i.text
        Quote.append(i.text)
    
    topauth = driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in topauth:
        topauth=i.text
        Author.append(i.text)
    
    typeofq = driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in typeofq:
        typeofq=i.text
        TypeOfQuotes.append(i.text)
    
    next_q=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_q.click()
    time.sleep(3)

# %%
len(Quote)
# Out:
# 1000

# %%
import pandas as pd
df = pd.DataFrame({'Quote':Quote,'Author Name':Author,'Type Of Quotes':TypeOfQuotes,})
df
# Out:
#                                                  Quote         Author Name  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                Type Of Quotes
# ...

# %%
#Write a python program  former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
driver.get("https://www.jagranjosh.com/")

# %%
GK = driver.find_element(By.XPATH,'//*[@id="1540978020504"]/div[1]/header/div[3]/ul/li[9]/a')
GK.click()

# %%
driver.execute_script('window.scrollTo(0,2000);')

# %%
PMs = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
PMs.click()

# %%
PMname=[]
PMBornDead=[]
Term_of_office=[]
Remark=[]

# %%
primemini=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in primemini:
    Name=i.text
    PMname.append(Name)

borndead=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in borndead:
    BD=i.text
    PMBornDead.append(BD)

officeterm=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in officeterm:
    office=i.text
    Term_of_office.append(office)

Primerem=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in Primerem:
    PMremark=i.text
    Remark.append(PMremark)

# %%
len(PMname), len(PMBornDead), len(Term_of_office), len(Remark)
# Out:
# (18, 18, 18, 18)

# %%
import pandas as pd
df = pd.DataFrame({'Prime Minister Name':PMname,'Born-Dead':PMBornDead,'Term of office':Term_of_office, 'Remark':Remark,})
df
# Out:
#             Prime Minister Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of office  \
# ...

# %%
#50 most expensive carsin the world.

# %%
driver.get("https://www.motor1.com/")

# %%
menu = driver.find_element(By.XPATH,'//*[@id="page_index_index_index"]/div[2]/div/div/div[1]/div')
menu.click()

# %%
features = driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/a')
features.click()

# %%
driver.execute_script('window.scrollTo(0,800);')

# %%
listofcars = driver.find_element(By.XPATH,'//*[@id="page_index_articles_browse"]/div[7]/div/div[1]/div[1]/div[3]/div/div[1]/h3/a')
listofcars.click()

# %%
Car_name = [] 
Car_price = []

# %%
carname=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carname:
    Name=i.text
    Car_name.append(Name)

carprice=driver.find_elements(By.XPATH,'//*[@id="article_box"]/div[1]/div[2]/div[1]//strong')
for i in carprice:
    price=i.text
    Car_price.append(price)

# %%
len(carname), len(carprice)
# Out:
# (51, 51)

# %%
import pandas as pd
df = pd.DataFrame({'Car Name':Car_name,'Car Price':Car_price,})
df
# Out:
#                             Car Name                    Car Price
# 0                      De Tomaso P72          Price: $1.3 Million
# 1                  Ferrari LaFerrari          Price: $1.4 Million
# 2                      Pagani Huayra          Price: $1.4 Million
# 3                       McLaren Elva
# 4                        Czinger 21C          Price: $1.7 Million
# 5                      Ferrari Monza          Price: $1.7 Million
# 6                 Gordon Murray T.33          Price: $1.7 Million
# 7                  Koenigsegg Gemera          Price: $1.7 Million
# 8                        Zenvo TSR-S          Price: $1.7 Million
# 9                 Hennessey Venom F5          Price: $1.7 Million
# 10                   Bentley Bacalar          Price: $1.8 Million
# 11     Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12            Bentley Mulliner Batur          Price: $1.9 Million
# 13                      Deus Vayanne          Price: $2.0 Million
# ...
